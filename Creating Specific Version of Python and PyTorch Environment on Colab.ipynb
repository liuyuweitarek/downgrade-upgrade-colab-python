# %% [markdown]
# # Creating a Specific Version of Python and PyTorch Environment on Colab
# This document will guide free users in creating a specific version of Python,
#  PyTorch and Tensorflow execution environment on Google Colab.
#
# Use Miniconda version 3.8 to create a Python 3.7 environment, which can use both PyTorch 1.7.1 and tensorflow 2.1.0 version.
#
# Author: [Tarek Liu](https://github.com/liuyuweitarek)
#
# Please note:
#
# 1. How to deal with Colab time limit?
#
#   This document does not overcome the time limit issue for free users, who will need to wait for a specific period before using it again. Therefore, please **make good use of Checkpoint to save and continue training progress**.
# 2. Can I use the realtime console with the Colab cell?
#
#   Unfortunately, I was not successful. In this usage, I cannot utilize the cell's ability to compile and execute programs in real-time. I can only use the "activate virtual environment" -> "run file" method. This makes development and debugging more annoyed. If you have a better approach, feel free to share it with me or submit a PR. Thank you!
# 3. Please use the version of Miniconda installer which is higher than the Python version you wish to use to create the virtual environment.

# %% [markdown]
# ## Connect to google drive space

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Forward to working directory

# %%
import os
os.chdir("/content/drive/MyDrive/custom_env_colab")

# %%
# %env PYTHONPATH = # /env/python
# Out:
# env: PYTHONPATH=# /env/python

# %% [markdown]
# ## Build virtual conda env

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !sudo chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update --yes conda
# Out:
# --2024-08-25 18:55:47--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh.1’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M  56.5MB/s    in 1.3s
#
# 2024-08-25 18:55:49 (56.5 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh.1’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package zlib conflicts for:
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# zlib==1.2.12=h7f8727e_1
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python==3.8.13=h12debd9_0 -> sqlite[version='>=3.38.0,<4.0a0'] -> zlib[version='>=1.2.13,<1.3.0a0|>=1.2.13,<2.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# python==3.8.13=h12debd9_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# tk==8.6.11=h1ccaba5_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# sqlite==3.38.2=hc218d9a_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.13,<1.3.0a0']
# zstd -> zlib[version='>=1.2.13,<1.3.0a0']
#
# Package pycparser conflicts for:
# zstandard -> cffi[version='>=1.11'] -> pycparser
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0'] -> pycparser
# cffi==1.15.0=py38hd667e15_1 -> pycparser
# pycparser==2.21=pyhd3eb1b0_0
# cryptography==36.0.0=py38h9ce1e76_0 -> cffi[version='>=1.12'] -> pycparser
#
# Package sqlite conflicts for:
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# sqlite==3.38.2=hc218d9a_0
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# python==3.8.13=h12debd9_0 -> sqlite[version='>=3.38.0,<4.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0|>=3.40.1,<4.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.38.0,<4.0a0|>=3.41.2,<4.0a0']
#
# Package cryptography conflicts for:
# conda==4.12.0=py38h06a4308_0 -> pyopenssl[version='>=16.2.0'] -> cryptography[version='>=35.0|>=41.0.5,<44']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> cryptography
# cryptography==36.0.0=py38h9ce1e76_0
# urllib3==1.26.8=pyhd3eb1b0_0 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=35.0|>=41.0.5,<44']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> cryptography[version='>=35.0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> cryptography[version='>=1.3.4']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> cryptography[version='>=1.3.4']
#
# Package _libgcc_mutex conflicts for:
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# conda-package-handling==1.8.1=py38h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# brotli-python -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pycosat==0.6.3=py38h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# sqlite==3.38.2=hc218d9a_0 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# tk==8.6.11=h1ccaba5_0 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# openssl==1.1.1n=h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cffi==1.15.0=py38hd667e15_1 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# brotlipy==0.7.0=py38h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# zstd -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ncurses==6.3=h7f8727e_2 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# lz4-c -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# zlib==1.2.12=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# _libgcc_mutex==0.1=main
# python==3.8.13=h12debd9_0 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cryptography==36.0.0=py38h9ce1e76_0 -> libgcc-ng -> _libgcc_mutex[version='*|0.1',build=main]
# libgcc-ng==9.3.0=h5101ec6_17 -> _libgcc_mutex[version='*|0.1',build=main]
# _openmp_mutex==4.5=1_gnu -> _libgcc_mutex==0.1=main
# libgomp==9.3.0=h5101ec6_17 -> _libgcc_mutex==0.1=main
# zstandard -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# readline==8.1.2=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
#
# Package six conflicts for:
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> six
# six==1.16.0=pyhd3eb1b0_1
#
# Package libstdcxx-ng conflicts for:
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# libffi==3.3=he6710b0_2 -> libstdcxx-ng[version='>=7.3.0']
# libstdcxx-ng==9.3.0=hd4cf53a_17
# python==3.8.13=h12debd9_0 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# lz4-c -> libstdcxx-ng[version='>=11.2.0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# brotli-python -> libstdcxx-ng[version='>=11.2.0']
# cffi==1.15.0=py38hd667e15_1 -> libffi[version='>=3.3'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0|>=7.5.0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# python==3.8.13=h12debd9_0 -> libstdcxx-ng[version='>=7.5.0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# zstd -> libstdcxx-ng[version='>=11.2.0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
#
# Package cffi conflicts for:
# cffi==1.15.0=py38hd667e15_1
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> cryptography -> cffi[version='>=1.12']
# urllib3==1.26.8=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0'] -> cffi[version='>=1.0.0|>=1.12']
# conda-package-streaming -> zstandard[version='>=0.15'] -> cffi[version='>=1.11']
# cryptography==36.0.0=py38h9ce1e76_0 -> cffi[version='>=1.12']
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> cryptography[version='>=35.0'] -> cffi[version='>=1.12']
# zstandard -> cffi[version='>=1.11']
#
# Package xz conflicts for:
# xz==5.2.5=h7b6447c_0
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# zstd -> xz[version='>=5.4.6,<6.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# python==3.8.13=h12debd9_0 -> xz[version='>=5.2.5,<6.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> xz[version='>=5.2.10,<6.0a0|>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> xz[version='>=5.2.5,<6.0a0|>=5.4.6,<6.0a0']
#
# Package libgcc-ng conflicts for:
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0'] -> libgcc-ng[version='>=11.2.0|>=7.3.0|>=7.5.0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# brotli-python -> libgcc-ng[version='>=11.2.0']
# zlib==1.2.12=h7f8727e_1 -> libgcc-ng[version='>=7.5.0']
# tk==8.6.11=h1ccaba5_0 -> libgcc-ng[version='>=7.5.0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> libgcc-ng[version='>=7.5.0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> cryptography[version='>=35.0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# cffi==1.15.0=py38hd667e15_1 -> libgcc-ng[version='>=7.5.0']
# cryptography==36.0.0=py38h9ce1e76_0 -> cffi[version='>=1.12'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> cryptography -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# readline==8.1.2=h7f8727e_1 -> libgcc-ng[version='>=7.5.0']
# cryptography==36.0.0=py38h9ce1e76_0 -> libgcc-ng
# zstd -> libgcc-ng[version='>=11.2.0']
# readline==8.1.2=h7f8727e_1 -> ncurses[version='>=6.3,<7.0a0'] -> libgcc-ng[version='>=11.2.0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> libgcc-ng[version='>=7.3.0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=7.5.0']
# libgcc-ng==9.3.0=h5101ec6_17
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# zstandard -> libgcc-ng[version='>=11.2.0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# cffi==1.15.0=py38hd667e15_1 -> libffi[version='>=3.3'] -> libgcc-ng[version='>=11.2.0|>=7.3.0']
# ncurses==6.3=h7f8727e_2 -> libgcc-ng[version='>=7.5.0']
# python==3.8.13=h12debd9_0 -> libffi[version='>=3.3,<3.4.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.3.0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# python==3.8.13=h12debd9_0 -> libgcc-ng[version='>=7.5.0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0']
# sqlite==3.38.2=hc218d9a_0 -> readline[version='>=8.0,<9.0a0'] -> libgcc-ng[version='>=11.2.0']
# tk==8.6.11=h1ccaba5_0 -> zlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=11.2.0']
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# conda==4.12.0=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> libgcc-ng[version='>=11.2.0|>=7.5.0|>=7.3.0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# pycosat==0.6.3=py38h7b6447c_1 -> libgcc-ng[version='>=7.3.0']
# sqlite==3.38.2=hc218d9a_0 -> libgcc-ng[version='>=7.5.0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# zstandard -> cffi[version='>=1.11'] -> libgcc-ng[version='>=7.5.0']
# lz4-c -> libgcc-ng[version='>=11.2.0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libgcc-ng[version='>=11.2.0|>=7.5.0']
# openssl==1.1.1n=h7f8727e_0 -> libgcc-ng[version='>=7.5.0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> libgcc-ng[version='>=7.3.0']
#
# Package ncurses conflicts for:
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# python==3.8.13=h12debd9_0 -> ncurses[version='>=6.3,<7.0a0']
# ncurses==6.3=h7f8727e_2
# sqlite==3.38.2=hc218d9a_0 -> readline[version='>=8.0,<9.0a0'] -> ncurses[version='>=6.3,<7.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# python==3.8.13=h12debd9_0 -> sqlite[version='>=3.38.0,<4.0a0'] -> ncurses[version='>=6.4,<7.0a0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# readline==8.1.2=h7f8727e_1 -> ncurses[version='>=6.3,<7.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> ncurses[version='>=6.3,<7.0a0|>=6.4,<7.0a0']
#
# Package ca-certificates conflicts for:
# cryptography==36.0.0=py38h9ce1e76_0 -> openssl -> ca-certificates
# python==3.8.13=h12debd9_0 -> openssl[version='>=1.1.1n,<1.1.2a'] -> ca-certificates
# openssl==1.1.1n=h7f8727e_0 -> ca-certificates
# ca-certificates==2022.3.29=h06a4308_1
#
# Package tk conflicts for:
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# python==3.8.13=h12debd9_0 -> tk[version='>=8.6.11,<8.7.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
# tk==8.6.11=h1ccaba5_0
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> tk[version='>=8.6.11,<8.7.0a0|>=8.6.12,<8.7.0a0']
#
# Package python conflicts for:
# conda-package-handling==1.8.1=py38h7f8727e_0 -> tqdm -> python[version='>=2.7']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0']
# conda==4.12.0=py38h06a4308_0 -> pyopenssl[version='>=16.2.0'] -> python[version='>=3.6|>=3.7,<3.8.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> colorama -> python
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6']
# six==1.16.0=pyhd3eb1b0_1 -> python
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0']
# cffi==1.15.0=py38hd667e15_1 -> pycparser -> python[version='>=3.6']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> cryptography[version='>=35.0'] -> python[version='>=3.8,<3.9.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0']
# pip==21.2.4=py38h06a4308_0 -> setuptools -> python[version='>=3.7,<3.8.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> cryptography -> python[version='>=3.8,<3.9.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6']
# colorama==0.4.4=pyhd3eb1b0_0 -> python
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0'] -> python[version='>=3.5|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6']
# requests==2.27.1=pyhd3eb1b0_0 -> certifi[version='>=2017.4.17'] -> python[version='<4.0|>=3.5|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
# python==3.8.13=h12debd9_0
# setuptools==61.2.0=py38h06a4308_0 -> certifi[version='>=2016.9.26'] -> python[version='>=3.7,<3.8.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6']
# brotli-python -> python[version='>=3.8,<3.9.0a0']
#
# Package ld_impl_linux-64 conflicts for:
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ld_impl_linux-64
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# six==1.16.0=pyhd3eb1b0_1 -> python -> ld_impl_linux-64
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# python==3.8.13=h12debd9_0 -> ld_impl_linux-64
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> ld_impl_linux-64
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ld_impl_linux-64
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> ld_impl_linux-64
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> ld_impl_linux-64
# ld_impl_linux-64==2.35.1=h7274673_9
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> ld_impl_linux-64
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> ld_impl_linux-64
#
# Package openssl conflicts for:
# openssl==1.1.1n=h7f8727e_0
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> cryptography -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# cryptography==36.0.0=py38h9ce1e76_0 -> openssl
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> cryptography[version='>=35.0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> cryptography[version='>=1.3.4'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# python==3.8.13=h12debd9_0 -> openssl[version='>=1.1.1n,<1.1.2a']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0|>=1.1.1s,<1.1.2a']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='>=1.1.1n,<1.1.2a|>=3.0.13,<4.0a0']
#
# Package lz4-c conflicts for:
# zstandard -> zstd[version='>=1.5.5,<1.5.6.0a0'] -> lz4-c[version='>=1.9.4,<1.10.0a0']
# zstd -> lz4-c[version='>=1.9.4,<1.10.0a0']
# lz4-c
#
# Package pysocks conflicts for:
# pysocks==1.7.1=py38h06a4308_0
# urllib3==1.26.8=pyhd3eb1b0_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package yaml conflicts for:
# yaml==0.2.5=h7b6447c_0
# conda==4.12.0=py38h06a4308_0 -> ruamel_yaml[version='>=0.11.14,<0.17'] -> yaml[version='>=0.2.5,<0.3.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> yaml[version='>=0.2.5,<0.3.0a0']
#
# Package brotlipy conflicts for:
# urllib3==1.26.8=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0']
# brotlipy==0.7.0=py38h27cfd23_1003
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
#
# Package pip conflicts for:
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> pip
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> pip
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> pip
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> pip
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> pip
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> pip
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# pip==21.2.4=py38h06a4308_0
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> pip
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> pip
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> pip
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> pip
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> pip
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> pip
# six==1.16.0=pyhd3eb1b0_1 -> python -> pip
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> pip
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> pip
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> pip
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> pip
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> pip
#
# Package ruamel_yaml conflicts for:
# conda==4.12.0=py38h06a4308_0 -> ruamel_yaml[version='>=0.11.14,<0.17']
# ruamel_yaml==0.15.100=py38h27cfd23_0
#
# Package libffi conflicts for:
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# python==3.8.13=h12debd9_0 -> libffi[version='>=3.3,<3.4.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> cffi[version='>=1.12'] -> libffi[version='>=3.3,<3.4.0a0|>=3.3|>=3.4,<3.5|>=3.4,<4.0a0']
# libffi==3.3=he6710b0_2
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> cffi[version='>=1.0.0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.3|>=3.4,<3.5|>=3.4,<4.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# cffi==1.15.0=py38hd667e15_1 -> libffi[version='>=3.3']
# zstandard -> cffi[version='>=1.11'] -> libffi[version='>=3.3,<3.4.0a0|>=3.3|>=3.4,<3.5|>=3.4,<4.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<3.5|>=3.4,<4.0a0']
#
# Package readline conflicts for:
# tqdm==4.63.0=pyhd3eb1b0_0 -> python[version='>=2.7'] -> readline[version='>=8.0,<9.0a0']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda-content-trust==0.1.1=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# pip==21.2.4=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# setuptools==61.2.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# cryptography==36.0.0=py38h9ce1e76_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# zstandard -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# colorama==0.4.4=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# cffi==1.15.0=py38hd667e15_1 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# sqlite==3.38.2=hc218d9a_0 -> readline[version='>=8.0,<9.0a0']
# readline==8.1.2=h7f8727e_1
# pycosat==0.6.3=py38h7b6447c_1 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# six==1.16.0=pyhd3eb1b0_1 -> python -> readline[version='>=8.0,<9.0a0']
# conda==4.12.0=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# wheel==0.37.1=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# brotlipy==0.7.0=py38h27cfd23_1003 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# requests==2.27.1=pyhd3eb1b0_0 -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# conda-package-streaming -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# python==3.8.13=h12debd9_0 -> readline[version='>=8.0,<9.0a0']
# pysocks==1.7.1=py38h06a4308_0 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
# urllib3==1.26.8=pyhd3eb1b0_0 -> python[version='<4.0'] -> readline[version='>=8.0,<9.0a0']
# certifi==2021.10.8=py38h06a4308_2 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='>=8.0,<9.0a0']
#
# Package _openmp_mutex conflicts for:
# python==3.8.13=h12debd9_0 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# conda-package-handling==1.8.1=py38h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# zstandard -> libgcc-ng[version='>=11.2.0'] -> _openmp_mutex
# ncurses==6.3=h7f8727e_2 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# openssl==1.1.1n=h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# pycosat==0.6.3=py38h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# readline==8.1.2=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# sqlite==3.38.2=hc218d9a_0 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# cffi==1.15.0=py38hd667e15_1 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# ruamel_yaml==0.15.100=py38h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# lz4-c -> libgcc-ng[version='>=11.2.0'] -> _openmp_mutex
# yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# brotli-python -> libgcc-ng[version='>=11.2.0'] -> _openmp_mutex
# _openmp_mutex==4.5=1_gnu
# tk==8.6.11=h1ccaba5_0 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# brotlipy==0.7.0=py38h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# zlib==1.2.12=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> _openmp_mutex[version='>=4.5']
# zstd -> libgcc-ng[version='>=11.2.0'] -> _openmp_mutex
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# cryptography==36.0.0=py38h9ce1e76_0 -> libgcc-ng -> _openmp_mutex[version='>=4.5']
# libgcc-ng==9.3.0=h5101ec6_17 -> _openmp_mutex[version='>=4.5']
#
# Package setuptools conflicts for:
# pip==21.2.4=py38h06a4308_0 -> setuptools
# conda==4.12.0=py38h06a4308_0 -> setuptools[version='>=31.0.1']
# setuptools==61.2.0=py38h06a4308_0
#
# Package certifi conflicts for:
# pip==21.2.4=py38h06a4308_0 -> setuptools -> certifi[version='>=2016.9.26']
# conda==4.12.0=py38h06a4308_0 -> requests[version='>=2.18.4,<3'] -> certifi[version='>=2016.9.26|>=2017.4.17']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> certifi
# requests==2.27.1=pyhd3eb1b0_0 -> certifi[version='>=2017.4.17']
# urllib3==1.26.8=pyhd3eb1b0_0 -> certifi
# setuptools==61.2.0=py38h06a4308_0 -> certifi[version='>=2016.9.26']
# certifi==2021.10.8=py38h06a4308_2
#
# Package pycosat conflicts for:
# pycosat==0.6.3=py38h7b6447c_1
# conda==4.12.0=py38h06a4308_0 -> pycosat[version='>=0.6.3']
#
# Package tqdm conflicts for:
# conda-package-handling==1.8.1=py38h7f8727e_0 -> tqdm
# tqdm==4.63.0=pyhd3eb1b0_0
# conda==4.12.0=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> tqdm
#
# Package idna conflicts for:
# urllib3==1.26.8=pyhd3eb1b0_0 -> idna[version='>=2.0.0']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> idna[version='>=2.0.0']
# conda==4.12.0=py38h06a4308_0 -> requests[version='>=2.18.4,<3'] -> idna[version='>=2.5,<4']
# requests==2.27.1=pyhd3eb1b0_0 -> idna[version='>=2.5,<4']
# idna==3.3=pyhd3eb1b0_0
#
# Package zstandard conflicts for:
# conda==4.12.0=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> zstandard[version='>=0.15']
# zstandard
# conda-package-streaming -> zstandard[version='>=0.15']
#
# Package colorama conflicts for:
# colorama==0.4.4=pyhd3eb1b0_0
# tqdm==4.63.0=pyhd3eb1b0_0 -> colorama
# conda-package-handling==1.8.1=py38h7f8727e_0 -> tqdm -> colorama
#
# Package wheel conflicts for:
# pip==21.2.4=py38h06a4308_0 -> wheel
# wheel==0.37.1=pyhd3eb1b0_0
#
# Package zstd conflicts for:
# zstd
# zstandard -> zstd[version='>=1.5.5,<1.5.6.0a0|>=1.5.5,<1.6.0a0']
# conda-package-streaming -> zstandard[version='>=0.15'] -> zstd[version='>=1.5.5,<1.5.6.0a0|>=1.5.5,<1.6.0a0']
#
# Package conda-package-handling conflicts for:
# conda==4.12.0=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0']
# conda-package-handling==1.8.1=py38h7f8727e_0
#
# Package urllib3 conflicts for:
# conda==4.12.0=py38h06a4308_0 -> requests[version='>=2.18.4,<3'] -> urllib3[version='>=1.21.1,<1.27|>=1.21.1,<3']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27']
# urllib3==1.26.8=pyhd3eb1b0_0
#
# Package charset-normalizer conflicts for:
# requests==2.27.1=pyhd3eb1b0_0 -> charset-normalizer[version='>=2.0.0,<2.1.0']
# charset-normalizer==2.0.4=pyhd3eb1b0_0
# conda==4.12.0=py38h06a4308_0 -> requests[version='>=2.18.4,<3'] -> charset-normalizer[version='>=2,<4|>=2.0.0,<2.1.0']
#
# Package pyopenssl conflicts for:
# pyopenssl==22.0.0=pyhd3eb1b0_0
# urllib3==1.26.8=pyhd3eb1b0_0 -> pyopenssl[version='>=0.14']
# conda==4.12.0=py38h06a4308_0 -> pyopenssl[version='>=16.2.0']
# requests==2.27.1=pyhd3eb1b0_0 -> urllib3[version='>=1.21.1,<1.27'] -> pyopenssl[version='>=0.14']
#
# Package conda-package-streaming conflicts for:
# conda==4.12.0=py38h06a4308_0 -> conda-package-handling[version='>=1.3.0'] -> conda-package-streaming[version='>=0.9.0']
# conda-package-streaming
#
# Package requests conflicts for:
# requests==2.27.1=pyhd3eb1b0_0
# conda==4.12.0=py38h06a4308_0 -> requests[version='>=2.18.4,<3']
#
# Package libgomp conflicts for:
# _openmp_mutex==4.5=1_gnu -> libgomp[version='>=7.5.0']
# libgcc-ng==9.3.0=h5101ec6_17 -> _openmp_mutex[version='>=4.5'] -> libgomp[version='>=7.5.0']
# libgomp==9.3.0=h5101ec6_17The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.35=0
#   - feature:|@/linux-64::__glibc==2.35=0
#   - brotli-python -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - brotlipy==0.7.0=py38h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cffi==1.15.0=py38hd667e15_1 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - conda-package-handling==1.8.1=py38h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - cryptography==36.0.0=py38h9ce1e76_0 -> libgcc-ng -> __glibc[version='>=2.17']
#   - libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng==9.3.0=h5101ec6_17 -> __glibc[version='>=2.17']
#   - libstdcxx-ng==9.3.0=hd4cf53a_17 -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - ncurses==6.3=h7f8727e_2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openssl==1.1.1n=h7f8727e_0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pycosat==0.6.3=py38h7b6447c_1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - python==3.8.13=h12debd9_0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - readline==8.1.2=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml==0.15.100=py38h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - sqlite==3.38.2=hc218d9a_0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tk==8.6.11=h1ccaba5_0 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - yaml==0.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib==1.2.12=h7f8727e_1 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zstandard -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=11.2.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.35
#
#
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# !conda create -n myenv python=3.7 --yes
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.7
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.7.2-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.38-h1181459_1
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1w-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.16-h7a1cb2a_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.38.4-py37h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python -m pip install -r requirements.txt --default-timeout=3000
# python -m pip install torch==1.7.1+cu101 --extra-index-url https://download.pytorch.org/whl --no-cache-dir
# Out:
# Collecting tensorflow-gpu==2.1.0
#   Using cached tensorflow_gpu-2.1.0-cp37-cp37m-manylinux2010_x86_64.whl (421.8 MB)
# Collecting protobuf==3.20.1
#   Using cached protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting wrapt>=1.11.1
#   Using cached wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Collecting scipy==1.4.1
#   Using cached scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
# Collecting keras-applications>=1.0.8
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting six>=1.12.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Using cached tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448 kB)
# Collecting google-pasta>=0.1.6
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting grpcio>=1.8.6
#   Using cached grpcio-1.62.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Collecting numpy<2.0,>=1.16.0
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 87.1 MB/s eta 0:00:00
# Collecting tensorboard<2.2.0,>=2.1.0
#   Using cached tensorboard-2.1.1-py3-none-any.whl (3.8 MB)
# Requirement already satisfied: wheel>=0.26 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorflow-gpu==2.1.0->-r requirements.txt (line 1)) (0.38.4)
# Collecting absl-py>=0.7.0
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Collecting astor>=0.6.0
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting keras-preprocessing>=1.1.0
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting gast==0.2.2
#   Using cached gast-0.2.2-py3-none-any.whl
# Collecting h5py
#   Using cached h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements.txt (line 1)) (65.6.3)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.8-py3-none-any.whl (66 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/myenv/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements.txt (line 1)) (2022.12.7)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorflow-estimator, zipp, wrapt, urllib3, typing-extensions, termcolor, six, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, idna, grpcio, gast, charset-normalizer, cachetools, astor, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, opt-einsum, keras-preprocessing, importlib-metadata, h5py, google-pasta, requests-oauthlib, markdown, keras-applications, google-auth, google-auth-oauthlib, tensorboard, tensorflow-gpu
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astor-0.8.1 cachetools-4.2.4 charset-normalizer-3.3.2 gast-0.2.2 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.62.3 h5py-3.8.0 idna-3.8 importlib-metadata-6.7.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.4.4 numpy-1.21.6 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.20.1 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-2.0.0 rsa-4.9 scipy-1.4.1 six-1.16.0 tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0 termcolor-2.3.0 typing-extensions-4.7.1 urllib3-2.0.7 werkzeug-2.2.3 wrapt-1.16.0 zipp-3.15.0
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl
# Collecting torch==1.7.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.7.1%2Bcu101-cp37-cp37m-linux_x86_64.whl (735.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.4/735.4 MB 234.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/envs/myenv/lib/python3.7/site-packages (from torch==1.7.1+cu101) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/envs/myenv/lib/python3.7/site-packages (from torch==1.7.1+cu101) (4.7.1)
# Installing collected packages: torch
# Successfully installed torch-1.7.1+cu101

# %% [markdown]
# ## Replace Cuda Modules
# If encounter error like:
#
# ```
# cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcublas.so.11.11.3.6': No such file or directory
# ```
# Keep running cells to [Execute your main function](https://colab.research.google.com/drive/14xMiWxgmwWKLHQr6zTGVLQ4JBdfdrcYJ#scrollTo=77KCEyR_XFkp) and then see more details in [What_if_encounter_not_found_error_while_replacing_cuda_modules](https://colab.research.google.com/drive/14xMiWxgmwWKLHQr6zTGVLQ4JBdfdrcYJ#scrollTo=O6XBpWU_kvn5&line=18&uniqifier=1)

# %%
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcublas.so.11.11.3.6 /usr/lib64-nvidia/libcublas.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusolver.so.11.4.1.48 /usr/lib64-nvidia/libcusolver.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusparse.so.11.7.5.86 /usr/lib64-nvidia/libcusparse.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcudart.so.11.8.89 /usr/lib64-nvidia/libcudart.so.10.1
# Out:
# cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcublas.so.11.11.3.6': No such file or directory
# cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusolver.so.11.4.1.48': No such file or directory
# cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusparse.so.11.7.5.86': No such file or directory
# cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcudart.so.11.8.89': No such file or directory

# %% [markdown]
# ## Fit cudnn version

# %%
# !tar -xzvf cudnn-10.1-linux-x64-v7.6.5.32.tgz
# !cp -P cuda/include/cudnn.h /usr/lib64-nvidia
# !cp -P cuda/lib64/libcudnn* /usr/lib64-nvidia
# !chmod a+r /usr/lib64-nvidia/libcudnn*
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.6.5
# cuda/lib64/libcudnn_static.a

# %% [markdown]
# ## Execute your main function here

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python main.py
# Out:
# 2024-08-25 18:58:32.929766: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:58:32.929919: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:58:32.929940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-08-25 18:58:34.283375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2024-08-25 18:58:34.303808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:34.304031: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 18:58:34.304101: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 18:58:34.566267: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 18:58:34.597879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 18:58:34.607037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 18:58:34.865752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 18:58:34.883632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 18:58:34.889052: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 18:58:34.889215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:34.889473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:34.889612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 18:58:34.890193: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2024-08-25 18:58:34.903405: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2024-08-25 18:58:34.903765: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6c7a780 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-08-25 18:58:34.903791: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2024-08-25 18:58:35.093864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:35.094165: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6c7cb00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-25 18:58:35.094199: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-08-25 18:58:35.094490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:35.094661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 18:58:35.094733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 18:58:35.094756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 18:58:35.094776: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 18:58:35.094795: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 18:58:35.094830: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 18:58:35.094853: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 18:58:35.094873: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 18:58:35.094972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:35.095169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:35.095311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 18:58:35.098514: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 18:58:39.288379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-08-25 18:58:39.288445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2024-08-25 18:58:39.288460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2024-08-25 18:58:39.293406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.293706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.293932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13475 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 1 Physical GPUs, 1 Logical GPUs
# default - Torch version: 1.7.1+cu101
# default - Torch cuda available: True
# default - Tensorflow version: 2.1.0
# WARNING:tensorflow:From main.py:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2024-08-25 18:58:39.302579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.302793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 18:58:39.302879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 18:58:39.303036: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 18:58:39.303064: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 18:58:39.303083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 18:58:39.303103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 18:58:39.303122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 18:58:39.303142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 18:58:39.303231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.303453: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.303915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 18:58:39.304210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-08-25 18:58:39.304355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2024-08-25 18:58:39.304378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2024-08-25 18:58:39.304525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.304758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:58:39.304940: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/device:GPU:0 with 13475 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# default - Tensorflow cuda available: True

# %% [markdown]
# ## What if encounter not found error while replacing cuda modules?
# Due to changes in the CUDA version on Google Colab, this step may produce errors.
# ```
# e.g. cp: cannot stat '/usr/local/cuda-11.8/targets/x86_64-linux/lib/libcublas.so.11.11.3.6': No such file or directory
# ```
# Please try replacing the files which console said it's missing or files listed below with their corresponding versions.
#
# ```
# 2024-08-25 18:14:43.631701: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:43.631808: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:43.631841: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-08-25 18:14:44.443595: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2024-08-25 18:14:44.461980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 18:14:44.462181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 18:14:44.462245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 18:14:44.462357: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:44.462461: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:44.463143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 18:14:44.463312: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:44.463431: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 18:14:44.468145: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# ```
# These files are missing:
#
# `libnvinfer.so.6` and `libnvinfer_plugin.so.6` are for TensorRT, if you don't use the package, could just ignore them.
#
# `libcublas.so.10`, `libcufft.so.10`, `libcusolver.so.10` and `libcusparse.so.10`. are modules which real matter to GPU usage. Let's find them!
#
# ---
# First, at new cell, check current colab cuda *.so version
# ```
# !ls -ll /usr/local
#
# #Output
#
# total 132
# drwxr-xr-x  1 root root  4096 Aug 25 16:06 bin
# drwxr-xr-x  3 root root  4096 Aug 22 13:42 colab
# drwxr-xr-x  2 root root  4096 Aug 25 16:06 compiler_compat
# drwxr-xr-x  2 root root  4096 Aug 25 16:06 condabin
# drwxr-xr-x  2 root root  4096 Aug 25 16:06 conda-meta
# lrwxrwxrwx  1 root root    22 Nov 10  2023 cuda -> /etc/alternatives/cuda
# lrwxrwxrwx  1 root root    25 Nov 10  2023 cuda-12 -> /etc/alternatives/cuda-12
# drwxr-xr-x  1 root root  4096 Nov 10  2023 cuda-12.2
# ```
# It's `cuda-12.2` now.
#
# Check whether missing files in the cuda-12.2 folder
# ```
# # libcublas.so.10, libcufft.so.10, libcusolver.so.10, libcusparse.so.10
# !ls -ll /usr/local/cuda-12.2/targets/x86_64-linux/lib/ | grep -E 'libcublas.so|libcufft.so|libcusolver.so|libcusparse.so'
#
# # OUTPUT
# lrwxrwxrwx 1 root root        15 Aug 16  2023 libcublas.so -> libcublas.so.12
# lrwxrwxrwx 1 root root        21 Aug 16  2023 libcublas.so.12 -> libcublas.so.12.2.5.6
# -rw-r--r-- 1 root root 106675248 Aug 16  2023 libcublas.so.12.2.5.6
# lrwxrwxrwx 1 root root        14 Aug 16  2023 libcufft.so -> libcufft.so.11
# lrwxrwxrwx 1 root root        22 Aug 16  2023 libcufft.so.11 -> libcufft.so.11.0.8.103
# -rw-r--r-- 1 root root 178387496 Aug 16  2023 libcufft.so.11.0.8.103
# lrwxrwxrwx 1 root root        17 Aug 16  2023 libcusolver.so -> libcusolver.so.11
# lrwxrwxrwx 1 root root        25 Aug 16  2023 libcusolver.so.11 -> libcusolver.so.11.5.2.141
# -rw-r--r-- 1 root root 115505432 Aug 16  2023 libcusolver.so.11.5.2.141
# lrwxrwxrwx 1 root root        17 Aug 16  2023 libcusparse.so -> libcusparse.so.12
# lrwxrwxrwx 1 root root        25 Aug 16  2023 libcusparse.so.12 -> libcusparse.so.12.1.2.141
# -rw-r--r-- 1 root root 263825056 Aug 16  2023 libcusparse.so.12.1.2.141
# ```
# Let's modify the command
# from
# ```
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcublas.so.11.11.3.6 /usr/lib64-nvidia/libcublas.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusolver.so.11.4.1.48 /usr/lib64-nvidia/libcusolver.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcusparse.so.11.7.5.86 /usr/lib64-nvidia/libcusparse.so.10
# !cp -P /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcudart.so.11.8.89 /usr/lib64-nvidia/libcudart.so.10.1
# ```
# to
# ```
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcublas.so.12.2.5.6 /usr/lib64-nvidia/libcublas.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcufft.so.11.0.8.103 /usr/lib64-nvidia/libcufft.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcusolver.so.11.5.2.141 /usr/lib64-nvidia/libcusolver.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcusparse.so.12.1.2.141 /usr/lib64-nvidia/libcusparse.so.10
# ```

# %% [markdown]
# ## Fix Error and try again

# %%
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcublas.so.12.2.5.6 /usr/lib64-nvidia/libcublas.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcufft.so.11.0.8.103 /usr/lib64-nvidia/libcufft.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcusolver.so.11.5.2.141 /usr/lib64-nvidia/libcusolver.so.10
# !cp -P /usr/local/cuda-12.2/targets/x86_64-linux/lib/libcusparse.so.12.1.2.141 /usr/lib64-nvidia/libcusparse.so.10

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python main.py
# Out:
# 2024-08-25 19:00:23.478262: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 19:00:23.478383: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2024-08-25 19:00:23.478402: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-08-25 19:00:24.470802: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2024-08-25 19:00:24.489992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.490245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 19:00:24.490313: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 19:00:24.539196: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 19:00:24.542583: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 19:00:24.543151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 19:00:24.548191: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 19:00:24.549505: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 19:00:24.554485: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 19:00:24.554669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.555006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.555169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 19:00:24.555594: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2024-08-25 19:00:24.562713: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2024-08-25 19:00:24.562985: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64ed5e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-08-25 19:00:24.563018: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2024-08-25 19:00:24.756014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.756299: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x64ef960 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-25 19:00:24.756328: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-08-25 19:00:24.756595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.756759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 19:00:24.756869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 19:00:24.756900: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 19:00:24.756923: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 19:00:24.756943: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 19:00:24.756963: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 19:00:24.756984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 19:00:24.757005: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 19:00:24.757089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.757282: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:24.757420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 19:00:24.757494: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 19:00:30.138778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-08-25 19:00:30.138864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2024-08-25 19:00:30.138884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2024-08-25 19:00:30.139187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.139500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.139726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13475 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 1 Physical GPUs, 1 Logical GPUs
# default - Torch version: 1.7.1+cu101
# default - Torch cuda available: True
# default - Tensorflow version: 2.1.0
# WARNING:tensorflow:From main.py:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2024-08-25 19:00:30.152919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.153124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2024-08-25 19:00:30.153195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2024-08-25 19:00:30.153212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2024-08-25 19:00:30.153227: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2024-08-25 19:00:30.153241: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2024-08-25 19:00:30.153255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2024-08-25 19:00:30.153270: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2024-08-25 19:00:30.153287: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2024-08-25 19:00:30.153365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.153597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.153749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2024-08-25 19:00:30.153778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-08-25 19:00:30.153789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2024-08-25 19:00:30.153799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2024-08-25 19:00:30.153944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.154169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-25 19:00:30.154347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/device:GPU:0 with 13475 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# default - Tensorflow cuda available: True
